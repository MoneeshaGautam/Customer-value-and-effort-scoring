# %%
# Import the libraries
from pymongo import MongoClient
import pandas as pd
from datetime import datetime
import warnings
# %run ./credentionals.ipynb import *
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\moneesha.gautam\python_scripts\CANbus_summary_report\venv\Lib\site-packages\IPython\core\magics\execution.py:701, in ExecutionMagics.run(self, parameter_s, runner, file_finder)
#     700     fpath = arg_lst[0]
# --> 701     filename = file_finder(fpath)
#     702 except IndexError as e:
#
# File c:\Users\moneesha.gautam\python_scripts\CANbus_summary_report\venv\Lib\site-packages\IPython\utils\path.py:90, in get_py_filename(name)
#      89         return py_name
# ---> 90 raise IOError("File `%r` not found." % name)
#
# OSError: File `'./credentionals.ipynb'` not found.
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 from datetime import datetime
#       5 import warnings
# ...

# %%
final_columns = [
    "vehicle_id", 
    "date", 
    "total_distance_travelled_in_Kms",
    "total_distance_travelled_in_Miles",
    "pure_EV_distance_travelled_in_Kms",
    "pure_EV_distance_travelled_in_Miles",
    "pure_EV_distance_travelled_ratio",
    "total_percent_of_battery_consumpted_above_24_percent",
    "energy_consumption_in_Kwhs",
    "fuel_consumption_in_gallons",
    "Kwhs_per_Mile",
    "Miles_per_Kwh",
    "Miles_per_Gallon"
    ]

final_dataframe = pd.DataFrame(columns = final_columns)

# %%
summary_columns=["Date","Start Odom","End Odom","KM Travelled","Miles Travelled","KWH Start","KWH End","KWH Used","KWH/M"]
summary=pd.DataFrame(columns=summary_columns)

# %%
veh_ids = [32246,32247,32265]
months = ["raw_2023_10"]

# %%
for month in months:
    for vehicle in veh_ids:
        try:
            # Connect to MongoDB
            client = MongoClient('mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false')

            # Select database
            db = client['CANbus']

            # Select collection
            collection = db[month]

            # Retrieve all documents from the collection for a specific vehicle with filtered columns
            documents = collection.find({"veid": vehicle}, {"odom": 1, "tden": 1, "time": 1})

            # Create a pandas dataframe from the collection
            data = pd.DataFrame(list(documents))

            # Save the data to a CSV file
            data.to_csv(f"data_{vehicle}_{month}.csv", index=False)

            # Close the connection
            client.close()

        except Exception as e:
            print(f"Error while connecting to MongoDB: {e}")
# Out:
# Error while connecting to MongoDB: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
# Error while connecting to MongoDB: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
# Error while connecting to MongoDB: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}

# %%
client = MongoClient('mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false')

# Select database
db = client['CANbus']

# Select collection
#collection = db[month]

# %%
for month in months:
    for vehicle in veh_ids:
        try:    
            # Connect to MongoDB
            client = MongoClient('mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false')

            # Select database
            db = client['CANbus']

            # Select collection
            collection = db[month]

            # Retrieve all documents from the collection for a specific vehicle with filtered columns
         # Retrieve all documents from the collection for a specific vehicle with filtered columns
            documents = month.find({"veid":vehicle}, {"odom":1, "tden":1, "time":1})

            # # Create a pandas dataframe from the collection
            data = pd.DataFrame(list(documents))
            pd.to_csv("data.csv",data)

            # # Convert the time column to timestamp format
            # data["time"] = pd.to_datetime(data["time"]).dt.strftime("%Y-%m-%d %H:%M:%S")

            # # Get a list of the unique dates
            # dates = pd.to_datetime(data["time"]).dt.date.unique()
            # dates = [str(date) for date in dates]

            # for i in range(len(dates)):
            #     try:
            #         # One day
            #         one_day = dates[i]
            #         day = data.loc[data['time'].str.contains(one_day, case=False)]

                   
            #         # Calculate the distance travelled in each observation
            #         day['distance'] = day['odom'].shift(-1) - day['odom']

            #         # Remove the obs with wrong odometer reading
            #         day = day[~((day["distance"]<0) | (day["distance"]>0.1))]

            #         # Calculate the total distance travelled in Kms
            #         total_distance_travelled_Kms = day["distance"].sum()

            #         # Calculate the total distance travelled in Miles
            #         total_distance_travelled_Miles = total_distance_travelled_Kms * 0.621371

            #         # Electricity consumption percent
            #         day['electricity_consumption_percent'] = day['ebsc'].shift(-1) - day['ebsc']

            #         # Fuel consumption percent
            #         day['fuel_consumption_percent'] = day['fllv'].shift(-1) - day['fllv']

            #         # Dataset by using the vehicle only as electric
            #         pure_ev = day[day["ebsc"]>24]

            #         # pure_ev['distance'] = pure_ev['odom'].shift(-1) - pure_ev['odom']
            #         pure_ev['electricity_consumption_percent'] = pure_ev['ebsc'].shift(-1) - pure_ev['ebsc']
            #         pure_ev = pure_ev[~((pure_ev["distance"]<0) | (pure_ev["distance"]>0.1))]
            #         pure_ev["sum_distance"] = pure_ev["distance"].cumsum()

            #         # Distance travelled as pure ev
            #         pure_ev_distance_travelled_in_Kms = pure_ev["sum_distance"].max()

            #         pure_ev_distance_travelled_in_Miles = pure_ev_distance_travelled_in_Kms * 0.621371

            #         # EV distance ratio
            #         pure_ev_distance_ratio = pure_ev_distance_travelled_in_Miles / total_distance_travelled_Miles

            #         # Total percent of battery above 24
            #         total_percent_of_battery_consumpted_above_24 = pure_ev[pure_ev["electricity_consumption_percent"]<0]["electricity_consumption_percent"].sum()

            #         # Energy consumption in Kwhs
            #         battery_kwhs = 18.1
            #         energy_consumption_in_Kwhs = battery_kwhs * (total_percent_of_battery_consumpted_above_24/100)

            #         # Total percent of fuel consumpted
            #         total_percent_of_fuel_consumpted = day[day['fuel_consumption_percent']<0]['fuel_consumption_percent'].sum()

            #         # Fuel consumption in gallons
            #         fuel_tank_capacity = 12.1
            #         fuel_consumption_in_gallons = fuel_tank_capacity * (total_percent_of_fuel_consumpted/100)

            #         # Kwhs per Miles driven
            #         Kwhs_per_Mile = abs(energy_consumption_in_Kwhs) / pure_ev_distance_travelled_in_Miles

            #         # Miles driven per Kwh
            #         Miles_per_Kwh = pure_ev_distance_travelled_in_Miles / abs(energy_consumption_in_Kwhs) 

            #         # Miles driven per gallon
            #         Miles_per_Gallon = total_distance_travelled_Miles / abs(fuel_consumption_in_gallons)

            #         row = {
            #             "vehicle_id": data["veid"][0], 
            #             "date": one_day, 
            #             "total_distance_travelled_in_Kms": total_distance_travelled_Kms,
            #             "total_distance_travelled_in_Miles": total_distance_travelled_Miles,
            #             "pure_EV_distance_travelled_in_Kms": pure_ev_distance_travelled_in_Kms,
            #             "pure_EV_distance_travelled_in_Miles": pure_ev_distance_travelled_in_Miles,
            #             "pure_EV_distance_travelled_ratio": pure_ev_distance_ratio,
            #             "total_percent_of_battery_consumpted_above_24_percent": total_percent_of_battery_consumpted_above_24,
            #             "energy_consumption_in_Kwhs": energy_consumption_in_Kwhs,
            #             "fuel_consumption_in_gallons": fuel_consumption_in_gallons,
            #             "Kwhs_per_Mile": Kwhs_per_Mile,
            #             "Miles_per_Kwh": Miles_per_Kwh,
            #             "Miles_per_Gallon": Miles_per_Gallon,
            #         }

            #         final_dataframe = pd.concat([final_dataframe, pd.DataFrame([row])], ignore_index=True)
                
            # except:
            #     pass

            # Close the connection
            client.close()
        except Exception as e:
            print(f"Error while connecting to MongoDB: {e}")
# Out:
# Error while connecting to MongoDB: slice indices must be integers or None or have an __index__ method
# Error while connecting to MongoDB: slice indices must be integers or None or have an __index__ method
# Error while connecting to MongoDB: slice indices must be integers or None or have an __index__ method

# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime, timedelta

# Replace with your actual connection string
connection_string = 'mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false'

try:
    # Connect to MongoDB
    client = MongoClient(connection_string)
    # Check if the connection was successful
    print("Connected successfully!")
    
    def get_previous_month():
    
        today = datetime.today()
        first_day_of_current_month = today.replace(day=1)
        last_day_of_previous_month = first_day_of_current_month - timedelta(days=1)
        print(last_day_of_previous_month)
        return last_day_of_previous_month.strftime('%B').lower()
    


    # List of vehicle IDs or other identifiers
    veh_ids = [32246,32247,32265]  # Replace with the actual vehicle IDs
    final_dataframe = pd.DataFrame()
    veh_ids






    # Close the connection
    client.close()
except Exception as e:
    print(f"Error while connecting to MongoDB: {e}")
# Out:
# Connected successfully!

# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime, timedelta

# Function to get the name of the previous month
def get_previous_month():
    today = datetime.today()
    first_day_of_current_month = today.replace(day=1)
    last_day_of_previous_month = first_day_of_current_month - timedelta(days=1)
    return last_day_of_previous_month.strftime('%B').lower()


# List of vehicle IDs or other identifiers
veh_ids = [32246,32247,32265]  # Replace with the actual vehicle IDs

# Initialize an empty DataFrame to store the final data
final_dataframe = pd.DataFrame()

# connection_string-moneesha= 'mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false'
connection_string='mongodb://CANbusUser:BaselayeR%20ProducT%20CalciuM@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false'

# Connect to MongoDB
client = MongoClient(connection_string)
print(veh_ids)
# Get the name of the previous month
previous_month = get_previous_month()
print(previous_month)

try:
    # Select database
    db = client['CANbus']

    # Select collection for the previous month
    collection = db[previous_month]

    # Loop over each vehicle ID
    for vehicle in veh_ids:
        # Retrieve all documents from the collection for a specific vehicle with filtered columns
        documents = collection.find({"veid":vehicle}, {"ebsc":0, "fllv":0, "odom":1, "spd":0, "time":1,"tden":1, "veid":1, "_id":0})

        # Create a pandas dataframe from the collection
        data = pd.DataFrame(list(documents))

        # Save the data to a CSV file
        filename = f"data_{previous_month}_{vehicle}.csv"  # Modify the filename as needed
        data.to_csv(filename, index=False)

except Exception as e:
    print(f"Error while processing data for {previous_month}: {e}")

# Close the connection
client.close()
# Out:
# [32246, 32247, 32265]
# october
# Error while processing data for october: Cannot do inclusion on field odom in exclusion projection, full error: {'ok': 0.0, 'errmsg': 'Cannot do inclusion on field odom in exclusion projection', 'code': 31253, 'codeName': 'Location31253'}

# %%
previous_month=get_previous_month()
previous_month
# Out:
# 'october'

# %%
from pymongo import MongoClient
import pandas as pd
from datetime import datetime, timedelta

# Function to get the name of the previous month
# def get_previous_month():
#     today = datetime.today()
#     first_day_of_current_month = today.replace(day=1)
#     last_day_of_previous_month = first_day_of_current_month - timedelta(days=1)
#     return last_day_of_previous_month.strftime('%B').lower()

# List of vehicle IDs or other identifiers
veh_ids = [32246,32247,32265]  # Replace with the actual vehicle IDs

# Initialize an empty DataFrame to store the final data
final_dataframe = pd.DataFrame()

# Connect to MongoDB
connection_string = 'mongodb://CANbusUser:admin@athena.vueconnected.com:27017/?authSource=admin&readPreference=primary&directConnection=true&ssl=false'
client = MongoClient(connection_string)

# Get the name of the previous month
previous_month = "raw_2023_07"
#get_previous_month()
previous_month

try:
    # Select database

    
    db = client['CANbus']

    # Create the collection name for the previous month
    #collection_name = f"data_{previous_month}"

    # Check if the collection exists before attempting to use it
    # if previous_month in db.list_collection_names():
        # Select collection for the previous month
    collection = db[previous_month]
    collection
       # Loop over each vehicle ID
    for vehicle in veh_ids:
            # Retrieve all documents from the collection for a specific vehicle with filtered columns
            documents = collection.find({"veid": vehicle}, {"odom": 1, "tden": 1, "time": 1})

            # Create a pandas dataframe from the collection
            data = pd.DataFrame(list(documents))

            # Save the data to a CSV file
            filename = f"data_{previous_month}_{vehicle}.csv"  # Modify the filename as needed
            data.to_csv(filename, index=False)

    # else:
    #     print(f"Collection {previous_month} not found in the database.")

except Exception as e:
    print(f"Error while processing data for {previous_month}: {e}")

# Close the connection
client.close()
# Out:
# Error while processing data for raw_2023_07: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
